# %% [markdown]
# # Step 2: Ad Generation via LLM API
#
# **Input:** `ad_generation_input.json` (from Step 1)
# **Output:** `ads_llm.json`
#
# **Model:** OpenAI — `gpt-5.4`
# **Generation:** Two-step — (2a) analysis per topic → (2b) A+B generated together with research context + few-shot example
#
# **Strategy A** (strength-amplifying): celebratory tone, draws from positive reviews
# **Strategy B** (problem-solving): reassurance tone, contrast-framing, draws from negative reviews
#
# API calls: 9 analysis + 9 generation = **18 calls total** (same as single-step)

# %% [markdown]
# ## 1. Install & Import

# %%
# %pip install openai --quiet

import json
import time
from openai import OpenAI
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Configuration

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise RuntimeError(
        "OPENAI_API_KEY not found."
    )

MODEL = "gpt-5.4"
client = OpenAI(api_key=OPENAI_API_KEY)
print(f"Model: {MODEL}")

# %% [markdown]
# ## 3. Load Input Data

# %%
with open('ad_generation_input.json', 'r', encoding='utf-8') as f:
    products = json.load(f)

print(f'Products loaded: {len(products)}')
for p in products:
    print(f"  {p['asin']} | {p['product_title'][:55]}")
    for t, d in p['topics'].items():
        print(f"    [{t}]  pos={d['n_positive_total']}  neg={d['n_negative_total']}  "
              f"pct_pos={d['pct_positive']}%")
# Out:
# Products loaded: 3
#   B002RXXOX8 | Davison Guitars Full Size Electric Guitar with 10-Watt
#     [Tuning stability]  pos=13  neg=12  pct_pos=52.0%
#     [Fret / neck setup]  pos=16  neg=13  pct_pos=55.2%
#     [String quality]  pos=16  neg=11  pct_pos=59.3%
#   B006CYVD5E | Directly Cheap 6 String Acoustic Guitar Pack, Right Han
#     [Customer service / returns]  pos=24  neg=27  pct_pos=47.1%
#     [String quality]  pos=10  neg=16  pct_pos=38.5%
#     [Tuning stability]  pos=11  neg=37  pct_pos=22.9%
#   B002X49732 | Crescent MG38-CF 38" Acoustic Guitar Starter Package, C
#     [Customer service / returns]  pos=19  neg=16  pct_pos=54.3%
#     [String quality]  pos=14  neg=18  pct_pos=43.8%
#     [Fret / neck setup]  pos=5  neg=7  pct_pos=41.7%

# %% [markdown]
# ## 4. Prompt Templates (Two-Step)
#
# ### Step 2a — Analysis prompt
# For each product × topic: ask GPT to extract (a) the specific positive quality to celebrate, and (b) the specific concern + product feature that resolves it.
# This grounds each ad in the actual review content before writing begins.
#
# ### Step 2b — Generation prompt
# Feed the analysis insights + research context + one few-shot A/B example pair into a single call that produces **both Strategy A and B together**.
# Generating both at once forces the model to actively contrast them.
#
# Key design decisions:
# - **Research context** explains *why* A and B must differ psychologically
# - **Few-shot example** shows the tone contrast concretely (customer service topic, different product)
# - **Combined A+B output** with explicit differentiability requirement prevents convergence
# - **Word target 40–55**, 2 sentences each

# %%
import re

RESEARCH_CONTEXT = """RESEARCH CONTEXT
----------------
These ads are part of an academic study comparing two advertising persuasion strategies:
  Strategy A — aspiration-driven: celebrate what customers love about this feature.
               Psychological appeal: desire and enthusiasm ("this product is great").
  Strategy B — trust-driven: resolve a specific buyer concern about this feature.
               Psychological appeal: reassurance and confidence ("your worry is answered").
The two ads must be psychologically distinct — a reader seeing only one ad with no label
must immediately know which strategy it represents."""

FEW_SHOT_EXAMPLE = """EXAMPLE (customer service topic — for tone reference only, do not copy content)
-------------------------------------------------------------------------------
Strategy A:
Packed with care and delivered fast, the Crescent MG38-CF arrives intact and exactly as
described—no missing parts, no surprises. Responsive support means any question gets
resolved quickly, making this the confident, easy choice for a first guitar purchase.

Strategy B:
Not every first guitar purchase goes smoothly, but Crescent's team responds fast and
resolves any issue before it interrupts your playing. Every MG38-CF ships fully packed
and ready to go—so you can buy with confidence and get straight to learning.

Why these work:
  A opens with a concrete positive (celebratory, aspirational).
  B opens with "Not every..." — implicit contrast that signals the concern without naming it,
  then immediately positions the product as the answer (reassuring, trust-driven).
-------------------------------------------------------------------------------"""


def build_analysis_prompt(product, topic, data):
    """Step 2a: extract the core insight for A and the core concern+feature for B."""
    pos = '\n'.join(f'- {r[:250]}' for r in data['positive_reviews'][:6])
    neg = '\n'.join(f'- {r[:250]}' for r in data['negative_reviews'][:6])
    return f"""You are preparing to write product advertisements. Analyse the reviews below.

PRODUCT: {product['product_title']}
TARGET FEATURE: {topic}

POSITIVE REVIEWS about {topic}:
{pos}

NEGATIVE REVIEWS about {topic}:
{neg}

YOUR TASK
---------
Answer in exactly this two-line format (no extra text):

POSITIVE INSIGHT: [1-2 sentences — what specific quality do satisfied customers praise about {topic}? Be concrete.]
CONCERN AND FEATURE: [1-2 sentences — what specific worry do unhappy customers have about {topic}? Name the ONE product feature that most directly addresses it.]"""


def parse_analysis(text):
    """Parse analysis output into (insight_a, insight_b)."""
    if not text:
        return None, None
    insight_a, insight_b = None, None
    m = re.search(r'POSITIVE INSIGHT:\s*(.+?)(?=CONCERN AND FEATURE:|$)', text, re.DOTALL | re.IGNORECASE)
    if m:
        insight_a = m.group(1).strip()
    m = re.search(r'CONCERN AND FEATURE:\s*(.+?)$', text, re.DOTALL | re.IGNORECASE)
    if m:
        insight_b = m.group(1).strip()
    return insight_a, insight_b


def build_generation_prompt(product, topic, data, insight_a, insight_b):
    """Step 2b: generate both A and B using insights + research context + few-shot."""
    features = '\n'.join(f'- {f}' for f in product['features'][:5]) if product['features'] else 'N/A'
    return f"""You are a senior advertising copywriter writing for an academic A/B study.

{RESEARCH_CONTEXT}

PRODUCT
-------
Name: {product['product_title']}
Brand: {product['brand']}
Description: {product['description'][:500]}
Key features:
{features}
Target feature: {topic}

ANALYSIS INSIGHTS (ground your writing in these)
-------------------------------------------------
Strategy A should celebrate: {insight_a}
Strategy B should resolve:   {insight_b}

{FEW_SHOT_EXAMPLE}

YOUR TASK
---------
Write BOTH ads (40–55 words, 2 sentences each) for the product above.
If a reader sees only one ad with no label, they must immediately know which strategy it is.

Rules for BOTH ads:
- Brand voice only — no customer attribution ("one customer said", "buyers report", etc.)
- One flowing paragraph — no bullet points, no lists
- No percentages, statistics, or counts
- Do NOT use: "outstanding value", "musical journey", "ideal for anyone", "affordable price",
  "beginners and experienced players alike", "take your sound to the next level", "making things right"

Strategy A rules:
- Tone: celebratory and enthusiastic
- Open with a concrete benefit tied to {topic} — not the product name, not "Discover"
- Use ONLY the positive insight above — no negatives or caveats, even indirectly
- Close with a clear reason this is the right choice for {topic}

Strategy B rules:
- Tone: reassuring and confident
- Open with a CONTRAST FRAME that implicitly signals the concern:
    e.g. "Not every [product type] does X — this one does."
    e.g. "[Specific feature] means [concern resolved], so [benefit]."
- NEVER open with: "Play with confidence", "Feel confident", "Rest assured",
  "When X matters", "Not all guitars", or any generic comfort phrase
- Second sentence names the specific product feature that makes the solution work
- Close with what the buyer gains — forward-looking

OUTPUT FORMAT — use exactly:
STRATEGY A:
[ad text]

STRATEGY B:
[ad text]"""


def parse_ads(text):
    """Parse Strategy A and B from combined generation output."""
    if not text:
        return None, None
    ad_a, ad_b = None, None
    m = re.search(r'STRATEGY A:\s*(.+?)(?=STRATEGY B:|$)', text, re.DOTALL | re.IGNORECASE)
    if m:
        ad_a = m.group(1).strip()
    m = re.search(r'STRATEGY B:\s*(.+?)$', text, re.DOTALL | re.IGNORECASE)
    if m:
        ad_b = m.group(1).strip()
    return ad_a, ad_b


print('Two-step prompt functions defined.')
print('\n--- Analysis prompt preview ---')
p0 = products[0]
t0 = list(p0['topics'].keys())[0]
print(build_analysis_prompt(p0, t0, p0['topics'][t0]))
# Out:
# Two-step prompt functions defined.
#
# --- Analysis prompt preview ---
# You are preparing to write product advertisements. Analyse the reviews below.
#
# PRODUCT: Davison Guitars Full Size Electric Guitar with 10-Watt Amp, Black - Right Handed Beginner Kit with Gig Bag and Accessories
# TARGET FEATURE: Tuning stability
#
# POSITIVE REVIEWS about Tuning stability:
# - Having a blast playing this great little guitar. Don't know that it has the &#34;guts&#34; for a hard-core serious guitarist who plays out live, but for jamming alone and with friends, it's outstanding. Comfortable, stays in tune, has a nice little k
# - Out of tune haha comes with a tuning pipe which is great! There's a loose bolt that shakes when you play the lowest string but should be fixed in no time. Amp is amazing. Another great buy from Amazon!
# - It's a cheap guitar that works. Doesn't stay in tune the best but it's a cheap Amazon guitar. No Ibanez here.
# - amp has a good buzz to it. but, I've only had to tune it once. stays on tune great and has a good solid sound.
# - Great Item was as described but guitar has issues staying in toon.
# - Loses tune somewhat quickly, and sounds horrible - but I'm pretty sure that it sounds bad because I'm bad at guitar...<br /><br />Perfect for use with RockSmith, which is what I got it for.
#
# NEGATIVE REVIEWS about Tuning stability:
# - Sounds like crap .... Amp  works when it wants to and wont work about half the time at all . Don't waste your time with this  cheap guitar .
# - Don’t waste your money, this guitar is crap.
# - I purchased this guitar as a Christmas gift for my son who is 8. The product came well packed and I was impressed with all facets with the exception of the guitar itself which has a problem staying in tune. You are lucky to play for more than 10 minu
# - guitar was warped and was stringed so poorly it came apart the second day of use...do not buy. horrible product. davison guitars are forever boiycotted by this guy.
# - does not stay in tune
# - This was the worst purchase i've made in my life. This guitar sucks horribly. Any beginners out there like me, don't waste your money on this. Spend the extra couple hundred and get something better. The guitar and amp both sound awful. For a beginne
#
# YOUR TASK
# ---------
# Answer in exactly this two-line format (no extra text):
#
# POSITIVE INSIGHT: [1-2 sentences — what specific quality do satisfied customers praise about Tuning stability? Be concrete.]
# CONCERN AND FEATURE: [1-2 sentences — what specific worry do unhappy customers have about Tuning stability? Name the ONE product feature that most directly addresses it.]

# %% [markdown]
# ## 5. Generate All 18 Ads (Two-Step)
#
# For each product × topic:
# 1. **Step 2a** — call analysis prompt → extract `insight_a` and `insight_b`
# 2. **Step 2b** — call generation prompt with insights → parse both Strategy A and B
#
# Total: 9 analysis calls + 9 generation calls = 18 calls

# %%
def call_openai(prompt, max_tokens=400, max_retries=3):
    """Call OpenAI API with retry logic."""
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model=MODEL,
                messages=[{"role": "user", "content": prompt}],
                temperature=0.7,
                max_completion_tokens=max_tokens,
            )
            return response.choices[0].message.content.strip()
        except Exception as e:
            wait = 2 ** attempt
            print(f'    [Attempt {attempt+1} failed: {e} — retrying in {wait}s]')
            time.sleep(wait)
    return None


ads_output = []
ad_count   = 0

for product in products:
    asin = product['asin']
    print(f"\n{'='*65}")
    print(f"{asin} | {product['product_title'][:55]}")

    product_ads = {
        'asin':          asin,
        'product_title': product['product_title'],
        'brand':         product['brand'],
        'ads':           {}
    }

    for topic, data in product['topics'].items():
        print(f"\n  Topic: {topic}")

        # Step 2a: analysis
        print(f"  [2a] Extracting insights...")
        analysis_raw        = call_openai(build_analysis_prompt(product, topic, data), max_tokens=150)
        insight_a, insight_b = parse_analysis(analysis_raw)
        print(f"    A: {insight_a}")
        print(f"    B: {insight_b}")
        time.sleep(1)

        # Step 2b: generation (both A and B in one call)
        print(f"  [2b] Generating A + B...")
        gen_raw    = call_openai(build_generation_prompt(product, topic, data, insight_a, insight_b), max_tokens=400)
        ad_a, ad_b = parse_ads(gen_raw)
        ad_count  += 2
        print(f"  [A] {ad_a}")
        print(f"  [B] {ad_b}")
        time.sleep(1)

        product_ads['ads'][topic] = {
            'strategy_a':   ad_a,
            'strategy_b':   ad_b,
            'insight_a':    insight_a,
            'insight_b':    insight_b,
            'pct_positive': data['pct_positive'],
            'pct_negative': data['pct_negative'],
        }

    ads_output.append(product_ads)

print(f'\nTotal ads generated: {ad_count}')
# Out:
# =================================================================
# B002RXXOX8 | Davison Guitars Full Size Electric Guitar with 10-Watt
#
#   Topic: Tuning stability
#   [2a] Extracting insights...
#     A: Satisfied customers say the guitar can hold its tuning surprisingly well for a budget beginner kit, sometimes needing very little retuning during casual practice or jam sessions. They praise being able to play comfortably without constant tuning interruptions.
#     B: Unhappy customers worry that the guitar goes out of tune quickly, sometimes within minutes, which makes practice frustrating and the sound seem poor. The ONE feature that most directly addresses this is tuning stability.
#   [2b] Generating A + B...
#   [A] Stays in tune through practice, riffs, and relaxed jam sessions, so your playing keeps its flow instead of stopping for constant adjustments. The Davison Guitars Full Size Electric Guitar kit lets you settle in and enjoy the sound, making it the right choice for tuning stability.
#   [B] Not every beginner electric guitar holds pitch for long—this one is built to keep practice sounding right and feeling less frustrating. Its adjustable chrome bridge helps support tuning stability, so you can spend more time learning, playing, and enjoying steady sound.
#
#   Topic: Fret / neck setup
#   [2a] Extracting insights...
#     A: Satisfied buyers say the guitar’s neck/fret setup is generally playable out of the box for beginners, and some note that any minor string-height issues can be adjusted with the included tools. They also describe the instrument as solidly built and a good starter value once set up.
#     B: Unhappy customers worry about poor neck and fret finishing, including fret buzz, sharp fret edges, low string action, and even warped necks that hurt playability. The ONE feature that most directly addresses this is the fret / neck setup.
#   [2b] Generating A + B...
#   [A] Smooth fretting and an easy-playing neck make practice feel natural from the start, so chords land cleaner and riffs come together faster. With a solid build, adjustable setup, and beginner-friendly playability, the Davison kit is a smart pick for a fret and neck setup that keeps you playing.
#   [B] Not every beginner electric arrives ready to feel comfortable in your hands—this one is built to give you a playable neck and frets that support steady practice. Its maple neck, finely finished fretboard, and adjustable bridge help dial in the setup, so you can start learning with fewer distractions and more confidence.
#
#   Topic: String quality
#   [2a] Extracting insights...
#     A: Satisfied buyers generally find the strings acceptable for a beginner guitar and say the instrument is playable once set up, with only occasional mentions of needing replacement strings. The praise is less about premium strings and more that the guitar works fine for entry-level use.
#     B: Unhappy customers most often complain that the strings are low quality and can break during tuning, making the guitar frustrating to use right away. The ONE feature that most directly addresses this is string quality.
#   [2b] Generating A + B...
#   [A] Smooth, playable strings make every first chord and riff feel easy, giving this guitar the welcoming response new players want right out of the case. The Davison Guitars Full Size Electric Guitar delivers dependable entry-level string performance, making it a smart pick for comfortable, ready-to-play practice.
#   [B] Not every beginner guitar stays dependable through tuning—this one is built to get you playing without early string frustration slowing you down. The Davison Guitars Full Size Electric Guitar pairs solid beginner-friendly construction with a ready-to-play setup, so you can tune up, plug in, and move forward with confidence.
#
# =================================================================
# B006CYVD5E | Directly Cheap 6 String Acoustic Guitar Pack, Right Han
#
#   Topic: Customer service / returns
#   [2a] Extracting insights...
#     A: Satisfied buyers say the guitar often arrives on time and in good condition, and some found it a worthwhile replacement after returning other damaged guitars. They appreciate getting the expected bundle and having no major complaints with the purchase process.
#     B: Unhappy customers worry about damaged or incomplete orders and then struggling to get help, refunds, or timely responses—especially when return windows are tight. The key feature that addresses this is responsive customer service with a clear, hassle-free return/refund process.
#   [2b] Generating A + B...
#   [A] Fast delivery and a smooth, no-stress purchase make this red acoustic guitar pack exciting to order from the start. Directly Cheap brings the full beginner bundle just as expected, with support that keeps everything easy—an excellent choice for customer service and returns.
#   [B] Not every first guitar order arrives complete and hassle-free—this one is backed to keep problems from becoming headaches. Directly Cheap supports the pack with responsive customer service and a clear return and refund process, so you can order, unpack, and start learning with confidence.
#
#   Topic: String quality
#   [2a] Extracting insights...
#     A: Satisfied buyers say the guitar can be fine for beginners once the stock strings are replaced, and some appreciate that it includes extra replacement strings. They also note the strings are acceptable enough for casual starter use after a quick upgrade.
#     B: Unhappy customers worry that the strings are poor quality, break easily, or won’t hold tune, sometimes causing problems during tuning. The ONE feature that most directly addresses this is string quality.
#   [2b] Generating A + B...
#   [A] Bright, ringing steel strings give every chord a clear, lively voice that makes practice feel exciting from the first strum. With extra replacement strings included in this teacher-approved starter pack, Directly Cheap gives new players the ready-to-play string setup that makes it a smart choice for satisfying acoustic tone.
#   [B] String quality can make tuning frustrating—this starter pack helps keep practice simple and steady from the start. The included extra replacement strings support the Directly Cheap 6 String Acoustic Guitar Pack with a practical backup, so you can restring easily and keep moving forward with confidence.
#
#   Topic: Tuning stability
#   [2a] Extracting insights...
#     A: Satisfied customers say the guitar’s tuning keys hold well and, after the strings stretch in, it stays in tune pretty reliably for beginner practice. Several reviewers specifically noted it holds its tune well once properly tuned.
#     B: Unhappy customers worry that the guitar is difficult or impossible to tune and that the cheap pegs won’t keep the strings in tune. The ONE feature that most directly addresses this is tuning stability.
#   [2b] Generating A + B...
#   [A] Stays in tune through practice, so every chord rings out bright and clear from the start. The Directly Cheap 6 String Acoustic Guitar Pack features geared tuning that helps hold pitch reliably once tuned, making it a strong choice for steady, satisfying beginner play.
#   [B] Not every starter acoustic holds pitch through practice—this one is built to help keep tuning steady, so learning feels smoother and less frustrating. Geared tuning is the feature that helps the Directly Cheap 6 String Acoustic Guitar Pack stay set, so you can spend more time playing and less time readjusting.
#
# =================================================================
# B002X49732 | Crescent MG38-CF 38" Acoustic Guitar Starter Package, C
#
#   Topic: Customer service / returns
#   [2a] Extracting insights...
#     A: Satisfied buyers praise responsive, helpful service: orders arrived on time and well-packed, staff apologized for mix-ups, and missing items were quickly sent out within days. They also appreciated smooth delivery and overall purchase support.
#     B: Unhappy customers worry about getting a defective or damaged guitar and then missing the return window or needing to send it back. The ONE product feature that most directly addresses this is the return policy / free return shipping.
#   [2b] Generating A + B...
#   [A] Fast delivery, careful packing, and responsive support make this starter package feel easy from the moment you order. With quick help for mix-ups and missing items, the Crescent MG38-CF is the right choice for customer service that keeps your first guitar purchase smooth.
#   [B] Not every first guitar arrives without worry—this one comes with a return policy that takes the pressure off if something isn’t right. Free return shipping gives the Crescent MG38-CF a practical safety net, so you can order now and focus on getting started.
#
#   Topic: String quality
#   [2a] Extracting insights...
#     A: Satisfied buyers say the strings are decent for a beginner guitar: several report the guitar sounds good, stays in tune reasonably well, and some had no string breakage after weeks of use. Others liked that the setup was easy to adapt, including swapping to nylon strings when desired.
#     B: Unhappy customers mainly worry that the guitar may come with poor-quality or incorrect steel strings, leading to bad tone, tuning problems, broken strings, and even bridge stress. The ONE feature that most directly addresses this is string type/quality—specifically, having the guitar correctly fitted with proper nylon strings.
#   [2b] Generating A + B...
#   [A] Bright steel strings give the Crescent MG38-CF a clear, lively tone that feels rewarding from the very first strum. With dependable tuning, easy playability, and a setup that adapts smoothly to your preference, it’s the right choice for string quality that keeps practice sounding good.
#   [B] Poorly matched strings can cause dull tone and tuning trouble—this starter guitar is built to avoid that from the start. The Crescent MG38-CF pairs wood construction and geared tuning with properly fitted strings, giving you steadier sound, less hassle, and a smoother path into playing.
#
#   Topic: Fret / neck setup
#   [2a] Extracting insights...
#     A: Satisfied buyers say the guitar’s neck and fretting feel acceptable for a starter instrument, with some noting it holds tune well and plays fine out of the box. When the neck is straight and setup is decent, customers find it enjoyable and easy enough for beginners to use.
#     B: Unhappy customers worry about poor fret and neck setup causing sharp fret edges, buzzing, rattling, or an apparently uneven/warped neck that makes the guitar hard to play. The ONE feature that most directly addresses this is the fret / neck setup.
#   [2b] Generating A + B...
#   [A] Smooth fretting and a straight-feeling neck make every first chords session easier and more fun. The Crescent MG38-CF 38" Acoustic Guitar Starter Package, COFFEE delivers a beginner-friendly setup that feels playable right out of the box, making it the smart pick for comfortable fret and neck performance.
#   [B] Not every starter acoustic arrives ready for easy fretting—this one is built to help avoid a frustrating first experience. Its linden binding and wood construction with geared tuning support a more stable neck and playable setup, so you can focus on learning with fewer distractions.
#
# Total ads generated: 18

# %% [markdown]
# ## 6. Save Output

# %%
with open('ads_llm.json', 'w', encoding='utf-8') as f:
    json.dump(ads_output, f, indent=2, ensure_ascii=False)

print('Saved to ads_llm.json')

print('\n--- Sanity Check ---')
for p in ads_output:
    print(f"\n{p['asin']} | {p['product_title'][:55]}")
    for topic, ads in p['ads'].items():
        a_ok = '✓' if ads['strategy_a'] else '✗ MISSING'
        b_ok = '✓' if ads['strategy_b'] else '✗ MISSING'
        print(f"  [{topic}]  A:{a_ok}  B:{b_ok}")
# Out:
# Saved to ads_llm.json
#
# --- Sanity Check ---
#
# B002RXXOX8 | Davison Guitars Full Size Electric Guitar with 10-Watt
#   [Tuning stability]  A:✓  B:✓
#   [Fret / neck setup]  A:✓  B:✓
#   [String quality]  A:✓  B:✓
#
# B006CYVD5E | Directly Cheap 6 String Acoustic Guitar Pack, Right Han
#   [Customer service / returns]  A:✓  B:✓
#   [String quality]  A:✓  B:✓
#   [Tuning stability]  A:✓  B:✓
#
# B002X49732 | Crescent MG38-CF 38" Acoustic Guitar Starter Package, C
#   [Customer service / returns]  A:✓  B:✓
#   [String quality]  A:✓  B:✓
#   [Fret / neck setup]  A:✓  B:✓

# %% [markdown]
# ## 7. Full Preview

# %%
with open('ads_llm.json', 'r', encoding='utf-8') as f:
    ads_output = json.load(f)

for p in ads_output:
    print(f"\n{'='*65}")
    print(f"{p['asin']} | {p['product_title']}")
    for topic, ads in p['ads'].items():
        a_words = len(ads['strategy_a'].split()) if ads['strategy_a'] else 0
        b_words = len(ads['strategy_b'].split()) if ads['strategy_b'] else 0
        print(f"\n  [{topic}]  ({ads['pct_positive']}% pos / {ads['pct_negative']}% neg)")
        print(f"  Insight A: {ads.get('insight_a', 'N/A')}")
        print(f"  Insight B: {ads.get('insight_b', 'N/A')}")
        print(f"  Strategy A ({a_words}w): {ads['strategy_a']}")
        print(f"  Strategy B ({b_words}w): {ads['strategy_b']}")
# Out:
# =================================================================
# B002RXXOX8 | Davison Guitars Full Size Electric Guitar with 10-Watt Amp, Black - Right Handed Beginner Kit with Gig Bag and Accessories
#
#   [Tuning stability]  (52.0% pos / 48.0% neg)
#   Insight A: Satisfied customers say the guitar can hold its tuning surprisingly well for a budget beginner kit, sometimes needing very little retuning during casual practice or jam sessions. They praise being able to play comfortably without constant tuning interruptions.
#   Insight B: Unhappy customers worry that the guitar goes out of tune quickly, sometimes within minutes, which makes practice frustrating and the sound seem poor. The ONE feature that most directly addresses this is tuning stability.
#   Strategy A (46w): Stays in tune through practice, riffs, and relaxed jam sessions, so your playing keeps its flow instead of stopping for constant adjustments. The Davison Guitars Full Size Electric Guitar kit lets you settle in and enjoy the sound, making it the right choice for tuning stability.
#   Strategy B (41w): Not every beginner electric guitar holds pitch for long—this one is built to keep practice sounding right and feeling less frustrating. Its adjustable chrome bridge helps support tuning stability, so you can spend more time learning, playing, and enjoying steady sound.
#
#   [Fret / neck setup]  (55.2% pos / 44.8% neg)
#   Insight A: Satisfied buyers say the guitar’s neck/fret setup is generally playable out of the box for beginners, and some note that any minor string-height issues can be adjusted with the included tools. They also describe the instrument as solidly built and a good starter value once set up.
#   Insight B: Unhappy customers worry about poor neck and fret finishing, including fret buzz, sharp fret edges, low string action, and even warped necks that hurt playability. The ONE feature that most directly addresses this is the fret / neck setup.
#   Strategy A (48w): Smooth fretting and an easy-playing neck make practice feel natural from the start, so chords land cleaner and riffs come together faster. With a solid build, adjustable setup, and beginner-friendly playability, the Davison kit is a smart pick for a fret and neck setup that keeps you playing.
#   Strategy B (52w): Not every beginner electric arrives ready to feel comfortable in your hands—this one is built to give you a playable neck and frets that support steady practice. Its maple neck, finely finished fretboard, and adjustable bridge help dial in the setup, so you can start learning with fewer distractions and more confidence.
#
#   [String quality]  (59.3% pos / 40.7% neg)
#   Insight A: Satisfied buyers generally find the strings acceptable for a beginner guitar and say the instrument is playable once set up, with only occasional mentions of needing replacement strings. The praise is less about premium strings and more that the guitar works fine for entry-level use.
#   Insight B: Unhappy customers most often complain that the strings are low quality and can break during tuning, making the guitar frustrating to use right away. The ONE feature that most directly addresses this is string quality.
#   Strategy A (46w): Smooth, playable strings make every first chord and riff feel easy, giving this guitar the welcoming response new players want right out of the case. The Davison Guitars Full Size Electric Guitar delivers dependable entry-level string performance, making it a smart pick for comfortable, ready-to-play practice.
#   Strategy B (49w): Not every beginner guitar stays dependable through tuning—this one is built to get you playing without early string frustration slowing you down. The Davison Guitars Full Size Electric Guitar pairs solid beginner-friendly construction with a ready-to-play setup, so you can tune up, plug in, and move forward with confidence.
#
# =================================================================
# B006CYVD5E | Directly Cheap 6 String Acoustic Guitar Pack, Right Handed, Red (000-BT-GA3810R-RDS+Lessons)
#
#   [Customer service / returns]  (47.1% pos / 52.9% neg)
#   Insight A: Satisfied buyers say the guitar often arrives on time and in good condition, and some found it a worthwhile replacement after returning other damaged guitars. They appreciate getting the expected bundle and having no major complaints with the purchase process.
#   Insight B: Unhappy customers worry about damaged or incomplete orders and then struggling to get help, refunds, or timely responses—especially when return windows are tight. The key feature that addresses this is responsive customer service with a clear, hassle-free return/refund process.
#   Strategy A (42w): Fast delivery and a smooth, no-stress purchase make this red acoustic guitar pack exciting to order from the start. Directly Cheap brings the full beginner bundle just as expected, with support that keeps everything easy—an excellent choice for customer service and returns.
#   Strategy B (44w): Not every first guitar order arrives complete and hassle-free—this one is backed to keep problems from becoming headaches. Directly Cheap supports the pack with responsive customer service and a clear return and refund process, so you can order, unpack, and start learning with confidence.
#
#   [String quality]  (38.5% pos / 61.5% neg)
#   Insight A: Satisfied buyers say the guitar can be fine for beginners once the stock strings are replaced, and some appreciate that it includes extra replacement strings. They also note the strings are acceptable enough for casual starter use after a quick upgrade.
#   Insight B: Unhappy customers worry that the strings are poor quality, break easily, or won’t hold tune, sometimes causing problems during tuning. The ONE feature that most directly addresses this is string quality.
#   Strategy A (49w): Bright, ringing steel strings give every chord a clear, lively voice that makes practice feel exciting from the first strum. With extra replacement strings included in this teacher-approved starter pack, Directly Cheap gives new players the ready-to-play string setup that makes it a smart choice for satisfying acoustic tone.
#   Strategy B (46w): String quality can make tuning frustrating—this starter pack helps keep practice simple and steady from the start. The included extra replacement strings support the Directly Cheap 6 String Acoustic Guitar Pack with a practical backup, so you can restring easily and keep moving forward with confidence.
#
#   [Tuning stability]  (22.9% pos / 77.1% neg)
#   Insight A: Satisfied customers say the guitar’s tuning keys hold well and, after the strings stretch in, it stays in tune pretty reliably for beginner practice. Several reviewers specifically noted it holds its tune well once properly tuned.
#   Insight B: Unhappy customers worry that the guitar is difficult or impossible to tune and that the cheap pegs won’t keep the strings in tune. The ONE feature that most directly addresses this is tuning stability.
#   Strategy A (44w): Stays in tune through practice, so every chord rings out bright and clear from the start. The Directly Cheap 6 String Acoustic Guitar Pack features geared tuning that helps hold pitch reliably once tuned, making it a strong choice for steady, satisfying beginner play.
#   Strategy B (51w): Not every starter acoustic holds pitch through practice—this one is built to help keep tuning steady, so learning feels smoother and less frustrating. Geared tuning is the feature that helps the Directly Cheap 6 String Acoustic Guitar Pack stay set, so you can spend more time playing and less time readjusting.
#
# =================================================================
# B002X49732 | Crescent MG38-CF 38" Acoustic Guitar Starter Package, COFFEE (Includes CrescentTM Digital E-Tuner)
#
#   [Customer service / returns]  (54.3% pos / 45.7% neg)
#   Insight A: Satisfied buyers praise responsive, helpful service: orders arrived on time and well-packed, staff apologized for mix-ups, and missing items were quickly sent out within days. They also appreciated smooth delivery and overall purchase support.
#   Insight B: Unhappy customers worry about getting a defective or damaged guitar and then missing the return window or needing to send it back. The ONE product feature that most directly addresses this is the return policy / free return shipping.
#   Strategy A (43w): Fast delivery, careful packing, and responsive support make this starter package feel easy from the moment you order. With quick help for mix-ups and missing items, the Crescent MG38-CF is the right choice for customer service that keeps your first guitar purchase smooth.
#   Strategy B (43w): Not every first guitar arrives without worry—this one comes with a return policy that takes the pressure off if something isn’t right. Free return shipping gives the Crescent MG38-CF a practical safety net, so you can order now and focus on getting started.
#
#   [String quality]  (43.8% pos / 56.2% neg)
#   Insight A: Satisfied buyers say the strings are decent for a beginner guitar: several report the guitar sounds good, stays in tune reasonably well, and some had no string breakage after weeks of use. Others liked that the setup was easy to adapt, including swapping to nylon strings when desired.
#   Insight B: Unhappy customers mainly worry that the guitar may come with poor-quality or incorrect steel strings, leading to bad tone, tuning problems, broken strings, and even bridge stress. The ONE feature that most directly addresses this is string type/quality—specifically, having the guitar correctly fitted with proper nylon strings.
#   Strategy A (45w): Bright steel strings give the Crescent MG38-CF a clear, lively tone that feels rewarding from the very first strum. With dependable tuning, easy playability, and a setup that adapts smoothly to your preference, it’s the right choice for string quality that keeps practice sounding good.
#   Strategy B (45w): Poorly matched strings can cause dull tone and tuning trouble—this starter guitar is built to avoid that from the start. The Crescent MG38-CF pairs wood construction and geared tuning with properly fitted strings, giving you steadier sound, less hassle, and a smoother path into playing.
#
#   [Fret / neck setup]  (41.7% pos / 58.3% neg)
#   Insight A: Satisfied buyers say the guitar’s neck and fretting feel acceptable for a starter instrument, with some noting it holds tune well and plays fine out of the box. When the neck is straight and setup is decent, customers find it enjoyable and easy enough for beginners to use.
#   Insight B: Unhappy customers worry about poor fret and neck setup causing sharp fret edges, buzzing, rattling, or an apparently uneven/warped neck that makes the guitar hard to play. The ONE feature that most directly addresses this is the fret / neck setup.
#   Strategy A (47w): Smooth fretting and a straight-feeling neck make every first chords session easier and more fun. The Crescent MG38-CF 38" Acoustic Guitar Starter Package, COFFEE delivers a beginner-friendly setup that feels playable right out of the box, making it the smart pick for comfortable fret and neck performance.
#   Strategy B (45w): Not every starter acoustic arrives ready for easy fretting—this one is built to help avoid a frustrating first experience. Its linden binding and wood construction with geared tuning support a more stable neck and playable setup, so you can focus on learning with fewer distractions.
